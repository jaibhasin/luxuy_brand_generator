# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
# %matplotlib inline


import os    
os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'

# %%
words = open('brands_list.txt', 'r').read().splitlines()
words[:10]
# Out:
# ['PINKO',
#  'DSQUARED2',
#  'TAGLIATORE',
#  'WOOYOUNGMI',
#  'MOSCHINO',
#  "MARC O'POLO",
#  'GIABORGHINI',
#  'SANTONI',
#  'Frette',
#  'RALPH LAUREN KIDS']

# %%
chars = sorted(list(set(''.join(words))))
stoi = {ch:i for i,ch in enumerate(chars)}
itos = {i:ch for ch,i in stoi.items()}
vocab_size = len(stoi)
print(len(stoi))
# Out:
# 65

# %%
block_size = 3

def build_set(words):
    X= []
    Y = []
    for w in words:
        context = [0]*block_size
        for ch in w+'.':
            ix = stoi[ch]
            X.append(context)
            Y.append(ix)
            context = context[1:]+[ix]
    X = torch.tensor(X)
    Y = torch.tensor(Y)
    return X, Y

n1 = len(words)*0.8
n2 = len(words)*0.9

Xtr,Ytr = build_set(words[:int(n1)])
X_cv , Y_cv = build_set(words[int(n1):int(n2)])
Xts,Yts = build_set(words[int(n2):])
Xtr.shape, Yts.shape, X_cv.shape, Y_cv.shape, Xts.shape, Yts.shape
# Out:
# (torch.Size([2333, 3]),
#  torch.Size([288]),
#  torch.Size([252, 3]),
#  torch.Size([252]),
#  torch.Size([288, 3]),
#  torch.Size([288]))

# %%
n_emb = 4
n_hidden = 100

# https://pytorch.org/docs/stable/nn.init.html

g = torch.Generator().manual_seed(2147483647)
C = torch.randn((vocab_size , n_emb) , generator=g)
W1 = torch.randn((n_emb*block_size , n_hidden) , generator=g) * (5/3)/(n_emb*block_size)**0.5
# b1 = torch.randn(n_hidden , generator=g) * 0.01
W2 = torch.randn((n_hidden , vocab_size) , generator=g) * 0.01 
b2 = torch.randn(vocab_size , generator=g) * 0.01

bngain = torch.ones((1,n_hidden))
bnbias = torch.zeros((1,n_hidden))

bnmean_running = torch.zeros((1,n_hidden))
bnstd_running = torch.ones((1,n_hidden))

params = [C,W1,W2,b2 , bngain , bnbias]
for p in params:
    p.requires_grad = True

# %%
@torch.no_grad()
def split_loss(split):
    x,y = {
        'train': (Xtr, Ytr),
        'cv': (X_cv, Y_cv),
        'test': (Xts, Yts)
    }[split]
    emb = C[x]
    embcat = emb.view(emb.shape[0], -1)
    hpreact = embcat @ W1 # + b1
    hpreact = bngain * (hpreact - bnmean_running) / (bnstd_running) + bnbias
    h = torch.tanh(hpreact)
    logits = h @ W2 + b2
    loss = F.cross_entropy(logits, y)
    print(f"{split} loss: {loss.item():.4f}")
    return loss.item()

# %%
max_steps = 2000
batch_size = 32
lossi = []

for i in range(max_steps):
    ix = torch.randint(0 , Xtr.shape[0] , (batch_size,) , generator=g)
    Xb , Yb = Xtr[ix] , Ytr[ix]

    #forward pass
    emb = C[Xb] 
    embcat = emb.view(emb.shape[0] , -1)
    hpreact = embcat @ W1 # + b1
    #batch normalization
    bnmeani = hpreact.mean(0 , keepdim=True)
    bnstdi = hpreact.std(0 , keepdim=True)
    hpreact = bngain * (hpreact - bnmeani) / (bnstdi) + bnbias

    with torch.no_grad():
        bnmean_running = 0.999*bnmean_running + 0.001*bnmeani
        bnstd_running = 0.999*bnstd_running + 0.001*bnstdi

    h = torch.tanh(hpreact)
    logits = h@W2 + b2
    loss = F.cross_entropy(logits , Yb)

    #backward pass
    for p in params:
        p.grad = None
    loss.backward()

    #upgrade
    lr = 0.1 if i < 100000 else 0.01
    for p in params:
        p.data -= lr * p.grad
    lossi.append(loss.log10().item())
    if i % 10000 == 0:
        print(f"{i:7d}/{max_steps}: {loss.item():.4f}")
# Out:
#       0/2000: 4.1539

# %%
plt.figure(figsize=(20,10))
plt.imshow(h.abs() > 0.99  , cmap = 'grey' , interpolation= 'nearest')
# white=True , black=False
# to check if outputs of tanh are saturated

# %%
plt.hist(h.view(-1).tolist() , 50)  #if values on -1/1 this will cause 1-t^2 to be 0 , -> reslting in no change in gradient
# Out:
# (array([155., 171., 129., 101.,  88.,  80.,  56.,  65.,  73.,  67.,  47.,
#          48.,  45.,  39.,  54.,  46.,  58.,  40.,  52.,  43.,  32.,  35.,
#          40.,  32.,  49.,  32.,  35.,  37.,  48.,  42.,  32.,  32.,  26.,
#          39.,  34.,  54.,  50.,  43.,  53.,  37.,  54.,  62.,  64.,  71.,
#          59.,  83., 111., 139., 152., 166.]),
#  array([-9.98678207e-01, -9.58733431e-01, -9.18788655e-01, -8.78843879e-01,
#         -8.38899102e-01, -7.98954326e-01, -7.59009550e-01, -7.19064773e-01,
#         -6.79119997e-01, -6.39175221e-01, -5.99230444e-01, -5.59285668e-01,
#         -5.19340892e-01, -4.79396116e-01, -4.39451339e-01, -3.99506563e-01,
#         -3.59561787e-01, -3.19617010e-01, -2.79672234e-01, -2.39727458e-01,
#         -1.99782681e-01, -1.59837905e-01, -1.19893129e-01, -7.99483526e-02,
#         -4.00035763e-02, -5.87999821e-05,  3.98859763e-02,  7.98307526e-02,
#          1.19775529e-01,  1.59720305e-01,  1.99665082e-01,  2.39609858e-01,
#          2.79554634e-01,  3.19499410e-01,  3.59444187e-01,  3.99388963e-01,
#          4.39333739e-01,  4.79278516e-01,  5.19223292e-01,  5.59168068e-01,
#          5.99112844e-01,  6.39057621e-01,  6.79002397e-01,  7.18947173e-01,
#          7.58891950e-01,  7.98836726e-01,  8.38781502e-01,  8.78726279e-01,
#          9.18671055e-01,  9.58615831e-01,  9.98560607e-01]),
#  <BarContainer object of 50 artists>)

# %%
plt.plot(lossi)

# %%
split_loss('train')
split_loss('cv')
# Out:
# train loss: 2.5469
# cv loss: 3.1561
# 3.1561102867126465

# %%
# now generating 10 names
g = torch.Generator().manual_seed(2147483647)
for _ in range(10):
    out = []
    context = [0] * block_size
    while True:
        emb = C[torch.tensor([context])]
        embcat = emb.view(emb.shape[0], -1)
        hpreact = embcat @ W1 # + b1
        hpreact = bngain * (hpreact - bnmean_running) / (bnstd_running) + bnbias
        h = torch.tanh(hpreact)
        logits = h @ W2 + b2
        probs = F.softmax(logits, dim=1)
        ix = torch.multinomial(probs, num_samples=1, generator=g).item()
        out.append(itos[ix])
        context = context[1:] + [ix]
        if ix == 0:
            break
    print(''.join(out))
# Out:
# WONA.D.Venlim.
# Gitenins.UNV
# Leuire.soecingnr
# Lpoert.Lancig.ninA
# A'.LinINCHUCT.EANNEMPC&I.CULEMLLANDAND.KLDA
# Glpecaari.sonc
# Rix.
# POIZOAGAITS
# RSTNE.Tagôtenc.dinult.JEINAARLSloLèna.eec
# DOMGO
